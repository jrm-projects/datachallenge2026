# %% [markdown]
# # Preprocessing des Donnees pour le Matching Produits - Facteurs d'Emission ADEME
#
# ## Objectif
# Preparer les donnees pour associer les produits de l'entreprise aux facteurs d'emission de la base ADEME.
#
# **Deux cas distincts (traites separement) :**
# - **Cas 1** : Matching avec les Facteurs d'Emission Physiques (FE_ADEME, TYPE='QTE')
# - **Cas 2** : Matching avec les Ratios Monetaires (RATIO_MONETAIRE, variable FE.LIB2 uniquement)

# %%
import pandas as pd
import numpy as np
import re
import unicodedata
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 100)

# %%
# CONFIGURATION - A MODIFIER SELON VOTRE ENVIRONNEMENT
DATA_INPUT_PATH = Path("./data/input")
DATA_OUTPUT_PATH = Path("./data/preprocessed")
DATA_OUTPUT_PATH.mkdir(parents=True, exist_ok=True)
FILE_PRODUITS = DATA_INPUT_PATH / "PRODUITS.xlsx"
FILE_FE_ADEME = DATA_INPUT_PATH / "FE_ADEME.xlsx"
FILE_RATIO_MONETAIRE = DATA_INPUT_PATH / "RATIO_MONETAIRE.xlsx"

# %%
# Chargement des donnees
df_produits = pd.read_excel(FILE_PRODUITS, sheet_name='BDD_PRODUITS')
df_fe_ademe = pd.read_excel(FILE_FE_ADEME, sheet_name='data_FE_ADEME')
df_ratio_monetaire = pd.read_excel(FILE_RATIO_MONETAIRE, sheet_name='data RM')

print(f"Produits entreprise : {df_produits.shape}")
print(f"Facteurs emission ADEME : {df_fe_ademe.shape}")
print(f"Ratios monetaires : {df_ratio_monetaire.shape}")
# Out:
# Produits entreprise : (47187, 7)
# Facteurs emission ADEME : (14824, 19)
# Ratios monetaires : (56, 9)

# %% [markdown]
# ## Analyse Exploratoire

# %%
print("PRODUITS ENTREPRISE")
print(f"Colonnes : {list(df_produits.columns)}")
print(f"\nValeurs manquantes :")
print(df_produits.isnull().sum())
display(df_produits.head())
# Out:
# PRODUITS ENTREPRISE
# Colonnes : ['PRODUIT.ID', 'DB.LIB', 'COMPTE.LIB', 'QTE.2022', 'QTE.2023', 'QTE.2024', 'QTE.Total']
#
# Valeurs manquantes :
# PRODUIT.ID        0
# DB.LIB            0
# COMPTE.LIB        0
# QTE.2022      27857
# QTE.2023      26958
# QTE.2024      25937
# QTE.Total         0
# dtype: int64
#    PRODUIT.ID                                   DB.LIB  \
# 0      601540            RAI DEPISTAGE (B50) REF RAID2
# 1      601615       SUPPLEMENT DIMANCHE (B20) REF 9004
# 2      246363                        RAI DEPISTAGE TIA
# 3      601541      PHENOTYPE RHESUS KELL (B40) REF RHK
# 4      601583  GROUPE SANGUIN ABO RH(D) (B35) REF ABOD
#
#                             COMPTE.LIB  QTE.2022  QTE.2023  QTE.2024  \
# 0   EFS EXAMENS GREFFES HLA ETMALADIES      35.0      35.0       NaN
# 1   EFS EXAMENS GREFFES HLA ETMALADIES       NaN      78.0       NaN
# 2   EFS EXAMENS GREFFES HLA ETMALADIES       NaN     245.0       NaN
# 3   EFS EXAMENS GREFFES HLA ETMALADIES      66.0     330.0       NaN
# 4   EFS EXAMENS GREFFES HLA ETMALADIES      66.0     330.0       NaN
#
#    QTE.Total
# 0       70.0
# 1       78.0
# 2      245.0
# 3      396.0
# 4      396.0

# %%
print("FACTEURS D'EMISSION ADEME")
print(f"Colonnes : {list(df_fe_ademe.columns)}")
print(f"\nTypes de FE (FE.TYPE) :")
print(df_fe_ademe['FE.TYPE'].value_counts())

# Separation FE physiques
df_fe_physique = df_fe_ademe[df_fe_ademe['FE.TYPE'] == 'QTE'].copy()
print(f"\nFE PHYSIQUES (TYPE='QTE') : {len(df_fe_physique)} lignes")
# Out:
# FACTEURS D'EMISSION ADEME
# Colonnes : ['FE.ADEME.ID', 'FE.BDD', 'FE.VAL', 'FE.UNITE', 'FE.Incertitude', 'FE.LIB1', 'FE.LIB2', 'FE.LIB3', 'FE.LIB4', 'FE.LIB5', 'FE.CAT1', 'FE.CAT2', 'FE.CAT3', 'FE.CAT4', 'FE.CAT5', 'FE.DATE-CREA', 'FE.DATE-MODIF', 'FE.DATE-VALID', 'FE.TYPE']
#
# Types de FE (FE.TYPE) :
# FE.TYPE
# QTE    14502
# ECO      322
# Name: count, dtype: int64
#
# FE PHYSIQUES (TYPE='QTE') : 14502 lignes

# %%
print("RATIOS MONETAIRES")
print(f"Colonnes : {list(df_ratio_monetaire.columns)}")
print(f"\nListe des ratios (FE.LIB2) :")
for i, lib in enumerate(df_ratio_monetaire['FE.LIB2'].values):
    print(f"  {i+1:2d}. {lib}")
# Out:
# RATIOS MONETAIRES
# Colonnes : ['FE.RM.ID', 'FE.BDD', 'FE.VAL', 'FE.UNITE', 'FE.Incertitude', 'FE.LIB1', 'FE.LIB2', 'FE.CAT1', 'FE.DATE-VALID']
#
# Liste des ratios (FE.LIB2) :
#    1. Agences de voyage, voyagistes, réservations – 2023
#    2. Arts, spectacles, musées, bibliothèques / Jeux de hasard – 2023
#    3. Assurance, réassurance, retraites (hors sécurité sociale) – 2023
#    4. Autres matériels de transport - 2023
#    5. Autres produits manufacturés - 2023
#    6. Autres produits minéraux non métalliques - 2023
#    7. Autres services personnels - 2023
#    8. Autres services spécialisés, scientifiques et techniques - 2023
#    9. Bois, liège (hors meubles) / Vannerie, sparterie - 2023
#   10. Cinéma, TV, musique, enregistrement / Programmation, diffusion – 2023
#   11. Commerce de détail, à l'exclusion des automobiles et des motocycles - 2023
#   12. Commerce de gros, à l'exclusion des automobiles et des motocycles - 2023
#   13. Constructions et travaux de construction - 2023
#   14. Edition - 2023
#   15. Entreposage et services auxiliaires des transports - 2023
#   16. Machines et équipements - 2023
#   17. Meubles  - 2023
#   18. Papier et carton - 2023
#   19. Produits chimiques - 2023
#   20. Produits de l'agriculture et de la chasse - 2023
#   21. Produits de l'industrie textile, articles d'habillement, cuir et articles en cuir - 2023
#   22. Produits de la pêche et de l'aquaculture - 2023
#   23. Produits des industries alimentaires, boissons et produits à base de tabac - 2023
#   24. Produits en caoutchouc et en plastique - 2023
#   25. Produits informatiques, électroniques et optiques - 2023
#   26. Produits métalliques, à l'exclusion des machines et équipements - 2023
#   27. Produits métallurgiques - 2023
#   28. Produits pharmaceutiques de base et préparations pharmaceutiques - 2023
#   29. Produits sylvicoles et services annexes - 2023
#   30. Programmation, conseil IT / Services d'information – 2023
#   31. Services annexes à l'agriculture et à la chasse - 2023
#   32. Services auxiliaires aux services financiers et aux assurances - 2023
#   33. Services d'administration publique et de défense/ services de sécurité sociale obligatoire - 2023
#   34. Services d'architecture et d'ingénierie/ services de contrôle et analyses techniques - 2023
#   35. Services d'hébergement et de restauration - 2023
#   36. Services de l'enseignement - 2023
#   37. Services de poste et de courrier - 2023
#   38. Services de publicité et d'études de marché - 2023
#   39. Services de recherche et développement scientifique - 2023
#   40. Services de réparation d'ordinateurs et de biens personnels et domestiques - 2023
#   41. Services de réparation et installation de machines et d'équipements - 2023
#   42. Services de santé humaine - 2023
#   43. Services de soutien à la pêche - 2023
#   44. Services de télécommunications - 2023
#   45. Services des ménages employeurs / Biens et services auto-produits – 2023
#   46. Services financiers, hors assurances et caisses de retraite - 2023
#   47. Services fournis par des organisations associatives - 2023
#   48. Services immobiliers - 2023
#   49. Services juridiques et comptables/ services des sièges sociaux/ conseil de gestion - 2023
#   50. Services liés à l'emploi - 2023
#   51. Services sportifs, récréatifs et de loisirs - 2023
#   52. Services vétérinaires - 2023
#   53. Transport par eau - 2023
#   54. Transports aériens - 2023
#   55. Transports terrestres et transports par conduites - 2023
#   56. Travaux d'impression et de reproduction - 2023

# %%
print("INCERTITUDE DES FACTEURS D'EMISSION")
print(f"\nFE Physiques :")
print(df_fe_physique['FE.Incertitude'].describe())
print(f"\nRatios Monetaires :")
print(df_ratio_monetaire['FE.Incertitude'].describe())
# Out:
# INCERTITUDE DES FACTEURS D'EMISSION
#
# FE Physiques :
# count    14502.000000
# mean         0.707753
# std          0.366808
# min          0.050000
# 25%          0.300000
# 50%          1.000000
# 75%          1.000000
# max          4.000000
# Name: FE.Incertitude, dtype: float64
#
# Ratios Monetaires :
# count    5.600000e+01
# mean     8.000000e-01
# std      1.120270e-16
# min      8.000000e-01
# 25%      8.000000e-01
# 50%      8.000000e-01
# 75%      8.000000e-01
# max      8.000000e-01
# Name: FE.Incertitude, dtype: float64

# %% [markdown]
# ## Fonctions de Preprocessing

# %%
def normalize_text(text):
    """Normalisation : minuscules, suppression accents et caracteres speciaux."""
    if pd.isna(text) or text is None:
        return ""
    text = str(text).lower().strip()
    text = unicodedata.normalize('NFD', text)
    text = ''.join(c for c in text if unicodedata.category(c) != 'Mn')
    text = re.sub(r'[^a-z0-9\s]', ' ', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def clean_product_description(text):
    """Nettoyage des descriptions produits : suppression refs, codes, etc."""
    if pd.isna(text) or text is None:
        return ""
    text = str(text)
    patterns = [
        r'ref\s*[:\s]*[a-z0-9\-\_\.]+',
        r'ref\s+constr[:\s]*[a-z0-9\-\_\.]+',
        r'ref\s+fourn[:\s]*[a-z0-9\-\_\.]+',
        r'ref\s+fab[:\s]*[a-z0-9\-\_\.]+',
        r'#\d+',
        r'\d{6,}',
        r'\b[a-z]{1,3}\d{4,}[a-z0-9]*\b',
        r'devis\s*n[^a-z]*[a-z0-9\-]+',
        r'substitution\s+ok[^,]*',
        r'gratuit[e]?\s+sur\s+marche',
    ]
    for pattern in patterns:
        text = re.sub(pattern, ' ', text, flags=re.IGNORECASE)
    return text

def extract_keywords(text):
    """Extraction des mots-cles significatifs."""
    stopwords = {
        'le', 'la', 'les', 'un', 'une', 'des', 'de', 'du', 'au', 'aux',
        'et', 'ou', 'en', 'pour', 'par', 'sur', 'avec', 'sans', 'dans',
        'ce', 'cette', 'ces', 'son', 'sa', 'ses', 'leur', 'leurs',
        'qui', 'que', 'quoi', 'dont',
        'est', 'sont', 'a', 'ont', 'ete', 'etre', 'avoir',
        'plus', 'moins', 'tres', 'bien', 'tout', 'tous', 'toute', 'toutes',
        'unite', 'unites', 'paire', 'paires', 'lot', 'lots', 'boite', 'boites',
        'ref', 'constr', 'fourn', 'fab',
        'cm', 'mm', 'ml', 'kg', 'gr', 'mg', 'l', 'm', 'x', 'n', 'v', 'd',
    }
    text = normalize_text(text)
    words = text.split()
    keywords = [w for w in words if len(w) > 2 and w not in stopwords and not w.isdigit()]
    return ' '.join(keywords)

def clean_ademe_lib(lib1, lib2, lib3):
    """Concatenation et nettoyage des libelles ADEME."""
    parts = []
    for lib in [lib1, lib2, lib3]:
        if pd.notna(lib) and str(lib).strip():
            text = str(lib)
            text = re.sub(r'"+', ' ', text)
            text = text.strip(',').strip()
            if text and text.lower() != 'nan':
                parts.append(text)
    return re.sub(r'\s+', ' ', ' '.join(parts)).strip()

def clean_ratio_monetaire_lib(lib2):
    """Nettoyage du libelle FE.LIB2 des ratios monetaires."""
    if pd.isna(lib2) or lib2 is None:
        return ""
    text = str(lib2)
    text = re.sub(r'[\-\u2013]\s*\d{4}\s*$', '', text)
    return text.strip()

# %% [markdown]
# ## Preprocessing des Produits Entreprise

# %%
df_produits_clean = df_produits.copy()
df_produits_clean['description_clean'] = df_produits_clean['DB.LIB'].apply(clean_product_description)
df_produits_clean['description_normalized'] = df_produits_clean['description_clean'].apply(normalize_text)
df_produits_clean['keywords'] = df_produits_clean['description_clean'].apply(extract_keywords)

print(f"Preprocessing produits termine : {len(df_produits_clean)} lignes")
# Out:
# Preprocessing produits termine : 47187 lignes

# %%
print("Exemples de preprocessing :")
for i in [0, 10, 50, 100, 200]:
    if i < len(df_produits_clean):
        row = df_produits_clean.iloc[i]
        print(f"\n[{i}] Original: {row['DB.LIB'][:80]}...")
        print(f"    Keywords: {row['keywords']}")
# Out:
# Exemples de preprocessing :
#
# [0] Original: RAI DEPISTAGE (B50) REF RAID2...
#     Keywords: rai depistage b50
#
# [10] Original: RETINOMAX PRINTER 5...
#     Keywords: retinomax printer
#
# [50] Original: PLANCHE DE TRANSFERT AMAGNETIQUEROLLBO DY RIGIDE MINI 90*50CMREF CONSTR ROLBO DY...
#     Keywords: planche transfert amagnetiquerollbo rigide mini 50cm rolbo
#
# [100] Original: COUSSIN UNIVERSEL PETIT FORMAT 30X40NE G0434 (LOT DE 2)...
#     Keywords: coussin universel petit format 30x40ne
#
# [200] Original: COUSSIN DISTAL SILICONE 80MM ST041REV8  (UNITE)...
#     Keywords: coussin distal silicone 80mm st041rev8

# %%
print("\nStatistiques :")
print(f"Produits total : {len(df_produits_clean)}")

print(f"description vide : {(df_produits_clean['description_normalized'] == '').sum()}")
print(f"Longueur moyenne description : {df_produits_clean['description_normalized'].str.split().str.len().mean():.1f} mots")

print(f"Keywords vides : {(df_produits_clean['keywords'] == '').sum()}")
print(f"Longueur moyenne keywords : {df_produits_clean['keywords'].str.split().str.len().mean():.1f} mots")

#df_produits_clean = df_produits_clean[df_produits_clean['keywords'] != '']

print(f"Keywords vides : {(df_produits_clean['keywords'] == '').sum()}")
print(f"Longueur moyenne keywords : {df_produits_clean['keywords'].str.split().str.len().mean():.1f} mots")
# Out:
# Statistiques :
# Produits total : 47187
# description vide : 2
# Longueur moyenne description : 8.4 mots
# Keywords vides : 7
# Longueur moyenne keywords : 5.1 mots
# Keywords vides : 7
# Longueur moyenne keywords : 5.1 mots

# %% [markdown]
# ## Preprocessing des Facteurs d'Emission Physiques (CAS 1)

# %%
df_fe_phys_clean = df_fe_physique.copy()
df_fe_phys_clean['description_raw'] = df_fe_phys_clean.apply(
    lambda row: clean_ademe_lib(row['FE.LIB1'], row['FE.LIB2'], row['FE.LIB3']), axis=1)
df_fe_phys_clean['description_normalized'] = df_fe_phys_clean['description_raw'].apply(normalize_text)
df_fe_phys_clean['keywords'] = df_fe_phys_clean['description_raw'].apply(extract_keywords)

print(f"Preprocessing FE physiques termine : {len(df_fe_phys_clean)} lignes")
# Out:
# Preprocessing FE physiques termine : 14502 lignes

# %%
print("Exemples FE physiques :")
for i in range(min(5, len(df_fe_phys_clean))):
    row = df_fe_phys_clean.iloc[i]
    print(f"\n[{i}] ID: {row['FE.ADEME.ID']}")
    print(f"    Combined: {row['description_raw'][:70]}...")
    print(f"    Keywords: {row['keywords']}")
# Out:
# Exemples FE physiques :
#
# [0] ID: 34052
#     Combined: Agribalyse, Salade César au poulet (salade verte,entrées et plats comp...
#     Keywords: agribalyse salade cesar poulet salade verte entrees plats composes salade cesar poulet salade verte fromage croutos sauce
#
# [1] ID: 33558
#     Combined: produits céréaliers, Agribalyse, Brioche fourrée crème pâtissière (typ...
#     Keywords: produits cerealiers agribalyse brioche fourree creme patissiere type chinois viennoiseries brioche fourree creme patissiere type chinois preemballee
#
# [2] ID: 32682
#     Combined: produits céréaliers, Agribalyse,biscuits sucrés , Goûter sec fourré ( ...
#     Keywords: produits cerealiers agribalyse biscuits sucres gouter sec fourre sandwiche parfum chocolat gouter sec fourre sandwiche parfum chocolat
#
# [3] ID: 32683
#     Combined: produits céréaliers, Agribalyse,biscuits sucrés , Goûter sec fourré ( ...
#     Keywords: produits cerealiers agribalyse biscuits sucres gouter sec fourre sandwiche parfum fruits gouter sec fourre sandwiche parfum fruits
#
# [4] ID: 32681
#     Combined: produits céréaliers, Agribalyse, Goûter sec fourré ( sandwiché ) parfu...
#     Keywords: produits cerealiers agribalyse gouter sec fourre sandwiche parfum lait vanille biscuits sucres gouter sec fourre sandwiche parfum lait vanille

# %%
print("\nStatistiques FE physiques :")
print(f"Total : {len(df_fe_phys_clean)}")
print(f"Keywords vides : {(df_fe_phys_clean['description_normalized'] == '').sum()}")
print(f"Keywords vides : {(df_fe_phys_clean['keywords'] == '').sum()}")
print(f"\nDistribution CAT1 :")
print(df_fe_phys_clean['FE.CAT1'].value_counts())
# Out:
# Statistiques FE physiques :
# Total : 14502
# Keywords vides : 0
# Keywords vides : 7
#
# Distribution CAT1 :
# FE.CAT1
# Achats de biens                   8722
# Réseaux de chaleur / froid        2510
# Electricité                        818
# Combustibles                       728
# Transport de marchandises          463
# Transport de personnes             354
# Process et émissions fugitives     318
# Traitement des déchets             312
# UTCF                               197
# Statistiques territoriales          60
# Achats de services                  20
# Name: count, dtype: int64

# %%
df_fe_phys_clean = df_fe_phys_clean[df_fe_phys_clean['keywords'] != ' ']

# %% [markdown]
# ## Preprocessing des Ratios Monetaires (CAS 2)

# %%
df_rm_clean = df_ratio_monetaire.copy()
df_rm_clean['description_raw'] = df_rm_clean['FE.LIB2'].apply(clean_ratio_monetaire_lib)
df_rm_clean['description_normalized'] = df_rm_clean['description_raw'].apply(normalize_text)
df_rm_clean['keywords'] = df_rm_clean['description_raw'].apply(extract_keywords)

print(f"Preprocessing ratios monetaires termine : {len(df_rm_clean)} lignes")
# Out:
# Preprocessing ratios monetaires termine : 56 lignes

# %%
print("Ratios monetaires preprocesses :")
for i in range(len(df_rm_clean)):
    row = df_rm_clean.iloc[i]
    print(f"\n[{i+1:2d}] ID: {row['FE.RM.ID']}")
    print(f"     Original: {row['FE.LIB2']}")
    print(f"     Cleaned : {row['description_raw']}")
    print(f"     Keywords: {row['keywords']}")
# Out:
# Ratios monetaires preprocesses :
#
# [ 1] ID: 43515
#      Original: Agences de voyage, voyagistes, réservations – 2023
#      Cleaned : Agences de voyage, voyagistes, réservations
#      Keywords: agences voyage voyagistes reservations
#
# [ 2] ID: 43460
#      Original: Arts, spectacles, musées, bibliothèques / Jeux de hasard – 2023
#      Cleaned : Arts, spectacles, musées, bibliothèques / Jeux de hasard
#      Keywords: arts spectacles musees bibliotheques jeux hasard
#
# [ 3] ID: 43475
#      Original: Assurance, réassurance, retraites (hors sécurité sociale) – 2023
#      Cleaned : Assurance, réassurance, retraites (hors sécurité sociale)
#      Keywords: assurance reassurance retraites hors securite sociale
#
# [ 4] ID: 43300
#      Original: Autres matériels de transport - 2023
#      Cleaned : Autres matériels de transport
#      Keywords: autres materiels transport
#
# [ 5] ID: 43365
#      Original: Autres produits manufacturés - 2023
#      Cleaned : Autres produits manufacturés
#      Keywords: autres produits manufactures
#
# [ 6] ID: 43305
#      Original: Autres produits minéraux non métalliques - 2023
#      Cleaned : Autres produits minéraux non métalliques
#      Keywords: autres produits mineraux non metalliques
#
# [ 7] ID: 43310
#      Original: Autres services personnels - 2023
#      Cleaned : Autres services personnels
#      Keywords: autres services personnels
#
# [ 8] ID: 43315
#      Original: Autres services spécialisés, scientifiques et techniques - 2023
#      Cleaned : Autres services spécialisés, scientifiques et techniques
#      Keywords: autres services specialises scientifiques techniques
#
# [ 9] ID: 43325
#      Original: Bois, liège (hors meubles) / Vannerie, sparterie - 2023
#      Cleaned : Bois, liège (hors meubles) / Vannerie, sparterie
#      Keywords: bois liege hors meubles vannerie sparterie
#
# [10] ID: 43375
#      Original: Cinéma, TV, musique, enregistrement / Programmation, diffusion – 2023
#      Cleaned : Cinéma, TV, musique, enregistrement / Programmation, diffusion
#      Keywords: cinema musique enregistrement programmation diffusion
#
# [11] ID: 43330
#      Original: Commerce de détail, à l'exclusion des automobiles et des motocycles - 2023
#      Cleaned : Commerce de détail, à l'exclusion des automobiles et des motocycles
#      Keywords: commerce detail exclusion automobiles motocycles
#
# [12] ID: 43335
#      Original: Commerce de gros, à l'exclusion des automobiles et des motocycles - 2023
#      Cleaned : Commerce de gros, à l'exclusion des automobiles et des motocycles
#      Keywords: commerce gros exclusion automobiles motocycles
#
# [13] ID: 43340
#      Original: Constructions et travaux de construction - 2023
#      Cleaned : Constructions et travaux de construction
#      Keywords: constructions travaux construction
#
# [14] ID: 43345
#      Original: Edition - 2023
#      Cleaned : Edition
#      Keywords: edition
#
# [15] ID: 43350
#      Original: Entreposage et services auxiliaires des transports - 2023
#      Cleaned : Entreposage et services auxiliaires des transports
#      Keywords: entreposage services auxiliaires transports
#
# [16] ID: 43355
#      Original: Machines et équipements - 2023
#      Cleaned : Machines et équipements
#      Keywords: machines equipements
#
# [17] ID: 43360
#      Original: Meubles  - 2023
#      Cleaned : Meubles
#      Keywords: meubles
#
# [18] ID: 43370
#      Original: Papier et carton - 2023
#      Cleaned : Papier et carton
#      Keywords: papier carton
#
# [19] ID: 43380
#      Original: Produits chimiques - 2023
#      Cleaned : Produits chimiques
#      Keywords: produits chimiques
#
# [20] ID: 43395
#      Original: Produits de l'agriculture et de la chasse - 2023
#      Cleaned : Produits de l'agriculture et de la chasse
#      Keywords: produits agriculture chasse
#
# [21] ID: 43405
#      Original: Produits de l'industrie textile, articles d'habillement, cuir et articles en cuir - 2023
#      Cleaned : Produits de l'industrie textile, articles d'habillement, cuir et articles en cuir
#      Keywords: produits industrie textile articles habillement cuir articles cuir
#
# [22] ID: 43385
#      Original: Produits de la pêche et de l'aquaculture - 2023
#      Cleaned : Produits de la pêche et de l'aquaculture
#      Keywords: produits peche aquaculture
#
# [23] ID: 43410
#      Original: Produits des industries alimentaires, boissons et produits à base de tabac - 2023
#      Cleaned : Produits des industries alimentaires, boissons et produits à base de tabac
#      Keywords: produits industries alimentaires boissons produits base tabac
#
# [24] ID: 43415
#      Original: Produits en caoutchouc et en plastique - 2023
#      Cleaned : Produits en caoutchouc et en plastique
#      Keywords: produits caoutchouc plastique
#
# [25] ID: 43420
#      Original: Produits informatiques, électroniques et optiques - 2023
#      Cleaned : Produits informatiques, électroniques et optiques
#      Keywords: produits informatiques electroniques optiques
#
# [26] ID: 43425
#      Original: Produits métalliques, à l'exclusion des machines et équipements - 2023
#      Cleaned : Produits métalliques, à l'exclusion des machines et équipements
#      Keywords: produits metalliques exclusion machines equipements
#
# [27] ID: 43430
#      Original: Produits métallurgiques - 2023
#      Cleaned : Produits métallurgiques
#      Keywords: produits metallurgiques
#
# [28] ID: 43435
#      Original: Produits pharmaceutiques de base et préparations pharmaceutiques - 2023
#      Cleaned : Produits pharmaceutiques de base et préparations pharmaceutiques
#      Keywords: produits pharmaceutiques base preparations pharmaceutiques
#
# [29] ID: 43440
#      Original: Produits sylvicoles et services annexes - 2023
#      Cleaned : Produits sylvicoles et services annexes
#      Keywords: produits sylvicoles services annexes
#
# [30] ID: 43445
#      Original: Programmation, conseil IT / Services d'information – 2023
#      Cleaned : Programmation, conseil IT / Services d'information
#      Keywords: programmation conseil services information
#
# [31] ID: 43400
#      Original: Services annexes à l'agriculture et à la chasse - 2023
#      Cleaned : Services annexes à l'agriculture et à la chasse
#      Keywords: services annexes agriculture chasse
#
# [32] ID: 43455
#      Original: Services auxiliaires aux services financiers et aux assurances - 2023
#      Cleaned : Services auxiliaires aux services financiers et aux assurances
#      Keywords: services auxiliaires services financiers assurances
#
# [33] ID: 43465
#      Original: Services d'administration publique et de défense/ services de sécurité sociale obligatoire - 2023
#      Cleaned : Services d'administration publique et de défense/ services de sécurité sociale obligatoire
#      Keywords: services administration publique defense services securite sociale obligatoire
#
# [34] ID: 43470
#      Original: Services d'architecture et d'ingénierie/ services de contrôle et analyses techniques - 2023
#      Cleaned : Services d'architecture et d'ingénierie/ services de contrôle et analyses techniques
#      Keywords: services architecture ingenierie services controle analyses techniques
#
# [35] ID: 43525
#      Original: Services d'hébergement et de restauration - 2023
#      Cleaned : Services d'hébergement et de restauration
#      Keywords: services hebergement restauration
#
# [36] ID: 43480
#      Original: Services de l'enseignement - 2023
#      Cleaned : Services de l'enseignement
#      Keywords: services enseignement
#
# [37] ID: 43485
#      Original: Services de poste et de courrier - 2023
#      Cleaned : Services de poste et de courrier
#      Keywords: services poste courrier
#
# [38] ID: 43490
#      Original: Services de publicité et d'études de marché - 2023
#      Cleaned : Services de publicité et d'études de marché
#      Keywords: services publicite etudes marche
#
# [39] ID: 43495
#      Original: Services de recherche et développement scientifique - 2023
#      Cleaned : Services de recherche et développement scientifique
#      Keywords: services recherche developpement scientifique
#
# [40] ID: 43500
#      Original: Services de réparation d'ordinateurs et de biens personnels et domestiques - 2023
#      Cleaned : Services de réparation d'ordinateurs et de biens personnels et domestiques
#      Keywords: services reparation ordinateurs biens personnels domestiques
#
# [41] ID: 43450
#      Original: Services de réparation et installation de machines et d'équipements - 2023
#      Cleaned : Services de réparation et installation de machines et d'équipements
#      Keywords: services reparation installation machines equipements
#
# [42] ID: 43505
#      Original: Services de santé humaine - 2023
#      Cleaned : Services de santé humaine
#      Keywords: services sante humaine
#
# [43] ID: 43390
#      Original: Services de soutien à la pêche - 2023
#      Cleaned : Services de soutien à la pêche
#      Keywords: services soutien peche
#
# [44] ID: 43510
#      Original: Services de télécommunications - 2023
#      Cleaned : Services de télécommunications
#      Keywords: services telecommunications
#
# [45] ID: 43520
#      Original: Services des ménages employeurs / Biens et services auto-produits – 2023
#      Cleaned : Services des ménages employeurs / Biens et services auto-produits
#      Keywords: services menages employeurs biens services auto produits
#
# [46] ID: 43530
#      Original: Services financiers, hors assurances et caisses de retraite - 2023
#      Cleaned : Services financiers, hors assurances et caisses de retraite
#      Keywords: services financiers hors assurances caisses retraite
#
# [47] ID: 43535
#      Original: Services fournis par des organisations associatives - 2023
#      Cleaned : Services fournis par des organisations associatives
#      Keywords: services fournis organisations associatives
#
# [48] ID: 43540
#      Original: Services immobiliers - 2023
#      Cleaned : Services immobiliers
#      Keywords: services immobiliers
#
# [49] ID: 43545
#      Original: Services juridiques et comptables/ services des sièges sociaux/ conseil de gestion - 2023
#      Cleaned : Services juridiques et comptables/ services des sièges sociaux/ conseil de gestion
#      Keywords: services juridiques comptables services sieges sociaux conseil gestion
#
# [50] ID: 43550
#      Original: Services liés à l'emploi - 2023
#      Cleaned : Services liés à l'emploi
#      Keywords: services lies emploi
#
# [51] ID: 43555
#      Original: Services sportifs, récréatifs et de loisirs - 2023
#      Cleaned : Services sportifs, récréatifs et de loisirs
#      Keywords: services sportifs recreatifs loisirs
#
# [52] ID: 43320
#      Original: Services vétérinaires - 2023
#      Cleaned : Services vétérinaires
#      Keywords: services veterinaires
#
# [53] ID: 43560
#      Original: Transport par eau - 2023
#      Cleaned : Transport par eau
#      Keywords: transport eau
#
# [54] ID: 43565
#      Original: Transports aériens - 2023
#      Cleaned : Transports aériens
#      Keywords: transports aeriens
#
# [55] ID: 43570
#      Original: Transports terrestres et transports par conduites - 2023
#      Cleaned : Transports terrestres et transports par conduites
#      Keywords: transports terrestres transports conduites
#
# [56] ID: 43575
#      Original: Travaux d'impression et de reproduction - 2023
#      Cleaned : Travaux d'impression et de reproduction
#      Keywords: travaux impression reproduction

# %% [markdown]
# ## Export des Fichiers

# %%
# Selection des colonnes
cols_produits = ['PRODUIT.ID', 'DB.LIB', 'COMPTE.LIB', 
                 'QTE.2022', 'QTE.2023', 'QTE.2024', 'QTE.Total',
                 'description_clean', 'description_normalized', 'keywords']

cols_fe_phys = ['FE.ADEME.ID', 'FE.VAL', 'FE.UNITE', 'FE.Incertitude',
                'FE.LIB1', 'FE.LIB2', 'FE.LIB3', 'FE.CAT1', 'FE.CAT2',
                'description_raw', 'description_normalized', 'keywords']

cols_rm = ['FE.RM.ID', 'FE.VAL', 'FE.UNITE', 'FE.Incertitude',
           'FE.LIB2', 'FE.CAT1',
           'description_raw', 'description_normalized', 'keywords']

df_produits_export = df_produits_clean[cols_produits].copy()
df_fe_phys_export = df_fe_phys_clean[cols_fe_phys].copy()
df_rm_export = df_rm_clean[cols_rm].copy()

# %%
print("RESUME DES FICHIERS")
print(f"\n1. Produits : {len(df_produits_export)} lignes")
print(f"2. FE Physiques (CAS 1) : {len(df_fe_phys_export)} lignes")
print(f"3. Ratios Monetaires (CAS 2) : {len(df_rm_export)} lignes")
# Out:
# RESUME DES FICHIERS
#
# 1. Produits : 47187 lignes
# 2. FE Physiques (CAS 1) : 14502 lignes
# 3. Ratios Monetaires (CAS 2) : 56 lignes

# %%
# Export CSV
df_produits_export.to_csv(DATA_OUTPUT_PATH / 'produits_preprocessed.csv', index=False, encoding='utf-8')
df_fe_phys_export.to_csv(DATA_OUTPUT_PATH / 'fe_physique_preprocessed.csv', index=False, encoding='utf-8')
df_rm_export.to_csv(DATA_OUTPUT_PATH / 'ratio_monetaire_preprocessed.csv', index=False, encoding='utf-8')

print("Fichiers exportes :")
print(f"  - {DATA_OUTPUT_PATH / 'produits_preprocessed.csv'}")
print(f"  - {DATA_OUTPUT_PATH / 'fe_physique_preprocessed.csv'}")
print(f"  - {DATA_OUTPUT_PATH / 'ratio_monetaire_preprocessed.csv'}")
# Out:
# Fichiers exportes :
#   - data/preprocessed/produits_preprocessed.csv
#   - data/preprocessed/fe_physique_preprocessed.csv
#   - data/preprocessed/ratio_monetaire_preprocessed.csv

# %% [markdown]
# ## Verification Qualite

# %%
# Doublons de keywords
duplicates = df_produits_export[df_produits_export.duplicated(subset=['keywords'], keep=False)]
duplicates_non_empty = duplicates[duplicates['keywords'] != '']
print(f"Produits avec keywords identiques : {len(duplicates_non_empty)}")

# Keywords vides
kw_vides = df_produits_export[df_produits_export['keywords'] == '']
print(f"Produits avec keywords vides : {len(kw_vides)}")
if len(kw_vides) > 0:
    for _, row in kw_vides.iterrows():
        print(f"  - {row['DB.LIB']}")
# Out:
# Produits avec keywords identiques : 23323
# Produits avec keywords vides : 7
#   -
#   - M1224D ##16/03/2022
#   - REFERENCES 11996-000017
#   - 96
#   - REF 2206488/1828473
#   - CQ BF
#   - BPK1520 65777 ID

# %%
print(f"""
Fichiers generes dans {DATA_OUTPUT_PATH} :
  1. produits_preprocessed.csv ({len(df_produits_export)} lignes)
  2. fe_physique_preprocessed.csv ({len(df_fe_phys_export)} lignes) - CAS 1
  3. ratio_monetaire_preprocessed.csv ({len(df_rm_export)} lignes) - CAS 2

""")
# Out:
# Fichiers generes dans data/preprocessed :
#   1. produits_preprocessed.csv (47187 lignes)
#   2. fe_physique_preprocessed.csv (14502 lignes) - CAS 1
#   3. ratio_monetaire_preprocessed.csv (56 lignes) - CAS 2
